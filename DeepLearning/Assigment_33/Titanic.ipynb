# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tdata = pd.read_csv('titanic.csv')
tdata.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
plt.hist(tdata.loc[(tdata['Sex']=='male') & (tdata['Age']),'Age'], bins=25, density=True, color='tab:gray', label='male')
plt.hist(tdata.loc[(tdata['Sex']=='female') & (tdata['Age']),'Age'], bins=25, density=True, color='tab:red', label='female')
plt.legend()
plt.title('__Age Distribution of Female and Male__')
plt.xlabel('AGE')
# Out:
# Text(0.5, 0, 'AGE')

# %%
plt.hist(tdata.loc[(tdata['Pclass']==1) & (tdata['Fare']),'Fare'], bins=10, density=True, color='tab:gray', label='Pcalss = 1')
plt.hist(tdata.loc[(tdata['Pclass']==2) & (tdata['Fare']),'Fare'], bins=10, density=True, color='tab:green', label='Pcalss = 2')
plt.hist(tdata.loc[(tdata['Pclass']==3) & (tdata['Fare']),'Fare'], bins=10, density=True, color='tab:red', label='Pcalss = 3')

plt.legend(frameon=False)
plt.title('__Fare Distribution__')
plt.xlabel('FARE')
# Out:
# Text(0.5, 0, 'FARE')
