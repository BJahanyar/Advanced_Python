# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
N = 500
std = 1.5
#create random shade 
Balloons_width = np.random.normal(17, std , N)
Balloons_length = np.random.normal(17, std , N)
Balloons_weight = np.random.normal(0.3, 0.1, N)

Melon_width = np.random.normal(5, std, N)
Melon_length = np.random.normal(15, std, N)
Melon_weight= np.random.normal(5, std, N)

#concatenate shades 
width = np.concatenate((Balloons_width, Melon_width))
length = np.concatenate((Balloons_length, Melon_length))
weight = np.concatenate((Balloons_weight, Melon_weight))

#save all Variable to have an array for INPUT X and Labels
X = np.array([width, length, weight]).T
Balloons_lable = np.zeros(N, dtype = 'int')
Melon_lable = np.ones(N, dtype = 'int')

#concatenate Labels for OUTPUT
Y = np.concatenate((Melon_lable,Balloons_lable))

# %%
#Printe Shape X and Transposed
X.shape
# Out:
# (1000, 3)

# %%
#Printe Shape Y
Y.shape
# Out:
# (1000,)

# %%
#Print random Feature in 2Dimention array witch are Inputs of Machine Learning in Futur
X
# Out:
# array([[19.45716281, 14.48383781,  0.37076498],
#        [19.28211645, 17.64031617,  0.37357958],
#        [18.32792306, 14.52948508,  0.20821794],
#        ...,
#        [ 4.29951127, 16.42069811,  4.92426796],
#        [ 3.13477212, 13.34836766,  3.46244992],
#        [ 4.20333004, 13.24105516,  2.33626056]])

# %%
#Print output Balloons = 1 & Melon 0 in 1Dimention array
#Y

# %%
#Draw 3D Plot
fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(X[0:N , 0] , X[0:N , 1] , X[0:N , 2],  c = 'RED')
ax.scatter(X[N: ,0] , X[N: ,1] , X[N: ,2] , c = 'BLACK')

plt.title("*3D scatter plot*", fontweight ='bold' , c = 'red')
ax.set_xlabel('_WIDTH_', fontweight ='bold')
ax.set_ylabel('_LENGHT_', fontweight ='bold')
ax.set_zlabel('_WEIGHT_', fontweight ='bold')
# Out:
# <ipython-input-161-3189fc365a45>:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# Text(0.5, 0, '_WEIGHT_')
